# %% [markdown]
# # k-means

# %% [markdown]
# ### malumotlarni ustma-ust tushmaydigan toplamlar klasterlarga ajratadi
# ### klaster ichki struktura (tuzilishga) egan bolmaydi
# - ichkaridagi obyektlar qandaydir qonuniyat boyicha bir-biriga boglangan bolmaydi
# ### klaster tarkibidagi nuqtalar judayam oxshash boladi
# ### klaster tashqarisidagi nuqtalar esa judayam farqli

# %%
from IPython.display import Image
Image('k-means_tushunchasi.jpg', width=600)

# %% [markdown]
# ## k-means algoritimi vazifasi rasmda korib turibmiz klaster ichidagi masofalarni minimallashtirish klasterlar orasidagi masofani esa maksimallashtirish

# %% [markdown]
# ## klaster ichidagi qiymatlarni hisoblash judaa oson rasmdagi formula
# - ozi bizda bitta nuqta bitta odam haqidagi malumotlar misol uchun

# %% [markdown]
# # aslida bu qiymatlarni normalizatsiya qilishimiz kerak yani o'rtasidagi qiymatlarni qandaydir (0 va 1) oraligiga tushurishimiz kerak

# %%
Image('k-means_2.jpg', width=600)

# %% [markdown]
# ## hozir biz tasodifiy nuqtalardan olib cluster yasadik ammo natija yamon chiqdi eng yaqin nuqtayam judaa uzoqda joylashgan
# - shu uchun asosiy kok nuqtalarni joyini almashtiramiz
# ### xatolikni hisoblash uchun tepadagi formuladan foydalanamiz

# %% [markdown]
# # endi kok nuqtalarni(sentroidlarni) qanday siljitamiz hoz qilgan chizmamizdagi nuqtalarni ortacha qiymatini hisoblab usha yerga sentroidlarni joylashtiramiz

# %%
Image('4_qadam.jpg', width=500)

# %% [markdown]
# ## bu siljitganimiz lekin natija hali ham yaxshi emas

# %%
Image('5_qadam.jpg', width=600)

# %% [markdown]
# ## mana endi natija biz kutganday boldi

# %% [markdown]
# ## qachonki hatolikni hisoblaydigan (SSE) formulasi kamayishdan tohtasa biz ham tohtaymiz ungacha sentroidlarni siljitaveramiz

# %% [markdown]
# # k-means algoritmi qanday ishlaydi?

# %% [markdown]
# - har bir klas uchun tasodifiy sentroidlarni tanlash
# - har bir nuqta sentroidgacha bolgan masofani olchash
# - har bir nuqtani eng yaqin sentroidga biriktirish
# - sentroidlarni siljitish
# - 2-4 qadamlarni sentroidlar siljishi tohtagunga qadar takkrorlash

# %% [markdown]
# # Biz k ni tahminan 3ga boldik
# ## uzi aslida k ni ham aniqlaydigan funksiya bor

# %%
Image('tirsak_k.jpg', width=500)

# %% [markdown]
# # mana bu yerda korishimiz mumkin tirsak deganda ozi qolni qayirilgan qismi tushuniladi
# # bu yerda k 3ga teng bolgan
